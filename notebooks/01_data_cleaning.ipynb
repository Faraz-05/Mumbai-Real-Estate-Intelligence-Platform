# %%
import pandas as pd
import numpy as np

locality_prices_monthly=pd.read_csv("../data/raw/locality_prices_monthly.csv")
metro_stations=pd.read_csv("../data/raw/metro_stations.csv")
secondary_sales=pd.read_csv("../data/raw/secondary_sales.csv")
under_construction=pd.read_csv("../data/raw/under_construction.csv")

print(locality_prices_monthly.head())
print("\n")
print(metro_stations.head())
print("\n")
print(secondary_sales.head())
print("\n")
print(under_construction.head())
# Out:
#   year_month      locality        region    tier  \
# 0    2020-01  Malabar Hill  South Mumbai  luxury
# 1    2020-02  Malabar Hill  South Mumbai  luxury
# 2    2020-03  Malabar Hill  South Mumbai  luxury
# 3    2020-04  Malabar Hill  South Mumbai  luxury
# 4    2020-05  Malabar Hill  South Mumbai  luxury
#
#    secondary_price_per_sqft_carpet_inr  secondary_price_per_sqft_carpet_usd  \
# 0                                69197                               830.37
# 1                                68992                               827.91
# 2                                73868                               886.42
# 3                                68395                               820.73
# 4                                69811                               837.74
#
#    underconstruction_price_per_sqft_carpet_inr  rental_per_sqft_monthly_inr  \
# 0                                        80017                        228.4
# ...

# %% [markdown]
# # Initial Dataset Inspection

# %%
print(locality_prices_monthly.shape)
print(locality_prices_monthly.info())
print(locality_prices_monthly.describe())

print("\n")

print(metro_stations.shape)
print(metro_stations.info())
print(metro_stations.describe())

print("\n")

print(secondary_sales.shape)
print(secondary_sales.info())
print(secondary_sales.describe())

print("\n")

print(under_construction.shape)
print(under_construction.info())
print(under_construction.describe())
# Out:
# (6384, 13)
# <class 'pandas.DataFrame'>
# RangeIndex: 6384 entries, 0 to 6383
# Data columns (total 13 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   year_month                                   6384 non-null   str
#  1   locality                                     6384 non-null   str
#  2   region                                       6384 non-null   str
#  3   tier                                         6384 non-null   str
#  4   secondary_price_per_sqft_carpet_inr          6384 non-null   int64
#  5   secondary_price_per_sqft_carpet_usd          6384 non-null   float64
#  6   underconstruction_price_per_sqft_carpet_inr  6384 non-null   int64
#  7   rental_per_sqft_monthly_inr                  6384 non-null   float64
#  8   n_listings_secondary                         6384 non-null   int64
#  9   n_listings_underconstruction                 6384 non-null   int64
# ...
